# %%
#url 
base_url = 'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=SNWD&locationid=FIPS:08&stationid=GHCND:USS0005K14S&units=standard&startdate=2024-01-07&enddate=2024-01-14&limit=1000'
locations_url = 'https://www.ncei.noaa.gov/cdo-web/api/v2/stations?datasetid=GHCND&datatypeid=SNWD&locationid=FIPS:08&startdate=2024-01-07&enddate=2024-01-14&limit=1000&offeset=0'
data_categories = 'https://www.ncei.noaa.gov/cdo-web/api/v2/datacategories?enddate=2024-06-10&offset=45&limit=1000'
data_types = 'https://www.ncei.noaa.gov/cdo-web/api/v2/datatypes?datasetid=GHCND&locationid=FIPS:08&enddate=2024-06-10&offset=0&limit=1000'
datasets = 'https://www.ncei.noaa.gov/cdo-web/api/v2/datasets?enddate=2024-06-10&dataypeid=PRCP&locationid=FIPS:08'
#datatypes: Precipitation (PRCP), Snow depth (SNWD)  










snow_depth_url = 'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=SNWD&locationid=FIPS:08&stationid=GHCND:USS0005K21&units=standard&startdate=2024-01-07&enddate=2024-01-14&limit=1000'
precipitation_url = 'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=PRCP&locationid=FIPS:08&stationid=GHCND:USS0005K09S&units=standard&startdate=2024-01-07&enddate=2024-01-14&limit=1000'
#precipitation and snow depth in inches
headers = {'token':'ptCSsKJigBiLLmlIdcjtNPMGhdYTpiXG'}
# r = requests.get(url = precipitation_url, headers=headers)


# r = requests.get(url = base_url, headers=headers)
# datadf = pd.json_normalize(r.json()['results'])
#iterate through each station to gather the snow data for that station. concat evenything together
# loc = requests.get(url = locations_url, headers=headers)
# locations = pd.json_normalize(loc.json()['results'])
# merged = pd.merge(datadf, locdf,how='left',left_on='station',right_on='id')
# import folium
# m = folium.Map(location=[locdf['latitude'].mean(), locdf['longitude'].mean()], zoom_start=5)

# for i, row in locdf.iterrows():
#     folium.Marker(
#         location=[row['latitude'], row['longitude']],
#         popup=row['name']
#     ).add_to(m)

# # Display the map
# m.save('names.html')

# %%
import requests
import pandas as pd
url = 'https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=SNWD&stationid=GHCND:USS0005K679S&units=standard&startdate=2024-01-07&enddate=2024-01-14&limit=1000'
headers = {'token':'ptCSsKJigBiLLmlIdcjtNPMGhdYTpiXG'}
r = requests.get(url = url, headers=headers)
datadf = pd.json_normalize(r.json()['results'])
print(datadf)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\noahp\Anaconda3\lib\site-packages\requests\models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\noahp\Anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\noahp\Anaconda3\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\noahp\Anaconda3\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Input In [2], in <cell line: 6>()
#       4 headers = {'token':'ptCSsKJigBiLLmlIdcjtNPMGhdYTpiXG'}
#       5 r = requests.get(url = url, headers=headers)
# ----> 6 datadf = pd.json_normalize(r.json()['results'])
#       7 print(datadf)
#
# File c:\Users\noahp\Anaconda3\lib\site-packages\requests\models.py:917, in Response.json(self, **kwargs)
#     915     raise RequestsJSONDecodeError(e.message)
#     916 else:
# --> 917     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: [Errno Expecting value] <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
# : 0

# %%
locations_url = 'https://www.ncei.noaa.gov/cdo-web/api/v2/stations?datasetid=GHCND&datatypeid=SNWD&locationid=FIPS:08&startdate=2024-01-07&enddate=2024-01-14&limit=1000&offeset=0'
headers = {'token':'ptCSsKJigBiLLmlIdcjtNPMGhdYTpiXG'}
r = requests.get(url = base_url, headers=headers)
print(r.json()['results'])
# Out:
# [{'date': '2024-01-07T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USS0005K14S', 'attributes': ',,T,', 'value': 35.0}, {'date': '2024-01-08T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USS0005K14S', 'attributes': ',,T,', 'value': 36.0}, {'date': '2024-01-09T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USS0005K14S', 'attributes': ',,T,', 'value': 38.0}, {'date': '2024-01-10T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USS0005K14S', 'attributes': ',,T,', 'value': 39.0}, {'date': '2024-01-11T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USS0005K14S', 'attributes': ',,T,', 'value': 39.0}, {'date': '2024-01-12T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USS0005K14S', 'attributes': ',,T,', 'value': 39.0}, {'date': '2024-01-13T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USS0005K14S', 'attributes': ',,T,', 'value': 39.0}, {'date': '2024-01-14T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USS0005K14S', 'attributes': ',,T,', 'value': 54.0}]

# %%
# 'https://www.ncei.noaa.gov/cdo-web/api/v2/stations?datasetid=GHCND&'
# 'datatypeid=SNWD&locationid=FIPS:08&startdate=2024-01-07&enddate=2024-01-14&limit=1000&offeset=0'
stations_url = (
    "https://www.ncei.noaa.gov/cdo-web/api/v2/stations?"
    "datasetid=GHCND&"
    "extent=46.826140,-121.804047,46.875683,-121.709290&"
    "limit=50"
)
headers = {'token':'ptCSsKJigBiLLmlIdcjtNPMGhdYTpiXG'}
resp = requests.get(stations_url, headers=headers)
print(resp.json())
# Out:
# {}

# %%
base_url = (
    "https://www.ncei.noaa.gov/access/services/data/v1?"
    "dataset=daily-summaries&"
    "dataTypes=SNWD,PRCP&"
    "bbox=46.826140,-121.804047,46.875683,-121.709290&"
    "startDate=2024-01-07&"
    "endDate=2024-01-14&"
    "format=json"
)
headers = {'token':'ptCSsKJigBiLLmlIdcjtNPMGhdYTpiXG'}
r = requests.get(url = base_url, headers=headers)

# df = pd.json_normalize(r.json()['results'])

# %%
r.json()
# Out:
# {'errorCode': 400,
#  'errorMessage': 'Bad Request',
#  'errors': [{'field': 'stations',
#    'message': 'A station is required.',
#    'value': None}]}

# %%
df.station.nunique()
# Out:
# 1000

# %%
df
# Out:
#                     date datatype            station attributes  value
# 0    2024-01-07T00:00:00     SNWD  GHCND:AU000005010       ,,E,    0.4
# 1    2024-01-07T00:00:00     SNWD  GHCND:AU000005901      ,X,E,   -0.4
# 2    2024-01-07T00:00:00     SNWD  GHCND:AU000006306       ,,E,    0.8
# 3    2024-01-07T00:00:00     SNWD  GHCND:AU000011801       ,,S,    2.0
# 4    2024-01-07T00:00:00     SNWD  GHCND:AU000015410       ,,E,   84.6
# ..                   ...      ...                ...        ...    ...
# 995  2024-01-07T00:00:00     SNWD  GHCND:GME00126526       ,,E,    0.0
# 996  2024-01-07T00:00:00     SNWD  GHCND:GME00126562       ,,E,    0.0
# 997  2024-01-07T00:00:00     SNWD  GHCND:GME00126586       ,,E,    0.0
# 998  2024-01-07T00:00:00     SNWD  GHCND:GME00126622       ,,E,    0.0
# 999  2024-01-07T00:00:00     SNWD  GHCND:GME00126670       ,,E,    0.0
#
# [1000 rows x 5 columns]

# %%
# ghcnd_extract_WA_WY_CO.py
import io
import requests
import pandas as pd

# URL (official)
url = "https://www.ncei.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt"

print("Downloading ghcnd-stations.txt from NOAA...")
r = requests.get(url)
print(r.json())
# Out:
# Downloading ghcnd-stations.txt from NOAA...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\noahp\Anaconda3\lib\site-packages\requests\models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\noahp\Anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\noahp\Anaconda3\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\noahp\Anaconda3\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Input In [2], in <cell line: 11>()
#       9 print("Downloading ghcnd-stations.txt from NOAA...")
#      10 r = requests.get(url)
# ---> 11 print(r.json())
#
# File c:\Users\noahp\Anaconda3\lib\site-packages\requests\models.py:917, in Response.json(self, **kwargs)
#     915     raise RequestsJSONDecodeError(e.message)
#     916 else:
# --> 917     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: [Errno Expecting value] <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>503 Service Unavailable</title>
# </head><body>
# <h1>Service Unavailable</h1>
# <p>The server is temporarily unable to service your
# request due to maintenance downtime or capacity
# problems. Please try again later.</p>
# <p>Additionally, a 503 Service Unavailable
# error was encountered while trying to use an ErrorDocument to handle the request.</p>
# </body></html>
# : 0
